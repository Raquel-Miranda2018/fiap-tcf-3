# %%
# Parâmetros de execução
DRIVE_PATH = '/content/drive/MyDrive/FASE 03'

# %% [markdown]
# # Notebook final - FASE 03
# Resumo do fluxo e instruções

# %%
# importe libs\ import pandas as pd
import joblib

# %% [markdown]
# ## Carregar modelo e metadata

# %%
model = joblib.load('model_output/lgb_model_final.joblib')
